# %%
import pandas as pd
import numpy as np
from IPython.display import clear_output
from aquarel import load_theme

# %% [markdown]
# ## Load dataset
# We first load and preprocess load demand data from [Albania](https://data.dtu.dk/articles/dataset/Albanian_national_electricity_consumption_and_weather_conditions_for_2016-2019/22786922) from a Parquet file format.

# %%
data = pd.read_parquet("../data/albania_res.parquet")
data.index = pd.to_datetime(data.index, utc="UTC")

# %% [markdown]
# ## Create data pipeline

# %% [markdown]
# Then we  sett up data transformation and scaling for time series forecasting. The goal is to prepare the dataset for modeling by defining the necessary parameters for the transformation and scaling processes.
#
# For this purpose we use ``DatasetObjective`` A utility from mlpforecast for managing dataset objectives, crucial for time series forecasting.

# %%
from mlpforecast.data.transform import DatasetObjective

# %% [markdown]
# To achive this we define set of variables as follow
#
# - target_series: The target variable to be predicted; in this case, "NetLoad".
# - unknown_features: Any fnumerical eatures not observed in the future etc demand price.
# - calendar_variables: Features derived from the calendar, such as hour and session.
# - known_calendar_features: Precomputed features that represent the calendar variables.
# - known_continuous_features: Continuous features used in the modeling process, including lagged variables and temperature.
# - input_window_size: The size of the input window for the model (96 time steps).
# - forecast_horizon: The forecasting horizon (48 time steps).

# %%
common_params = {
    "target_series": ["NetLoad"],
    "unknown_features": [],
    "calendar_variables": ["HOUR", "Session"],
    "known_calendar_features": ["HOUR-cosin", "Session-cosin"],
    "known_continuous_features": ["NetLoad_lag_48", "NetLoad_lag_336", "Temperature"],
    "input_window_size": 96,
    "forecast_horizon": 48,
}

# %% [markdown]
# Then we specify how we want to transform the data adding more features such as lagging or rolling window and scaling function using sklaern processing scaler

# %%
from sklearn.preprocessing import (
    MinMaxScaler,
    RobustScaler,
    PowerTransformer,
)

data_params = {
    "input_scaler": PowerTransformer('yeo-johnson'),
    "target_scaler": PowerTransformer('box-cox'),
    "lags": [1, 7],
    "windows": [],
    "window_funcs": ["mean"],
    "period": "30min",
    "date_column": "timestamp",
}

# %% [markdown]
# We update the parameters and define the  ``DatasetObjective``. This line ```data_params.update(common_params)`` merges common_params into data_params, ensuring all relevant settings are included for the dataset transformation.

# %%
data_params.update(common_params)
ds = DatasetObjective(**data_params)
clear_output()

# %% [markdown]
# Since the dataset objective is an instance of sklearn object it implement two main function ```fit``` and ```transform```. The ```fit```  fit the DatasetObjective object (ds) to the provided data, ensuring that the transformations and scaling parameters are applied correctly to the dataset.

# %%
ds.fit(data.reset_index())
clear_output()

# %% [markdown]
# This fitted data processing pipeline associated with the DatasetObjective instance contains all the transformation steps that will be applied to the dataset.

# %%
ds.data_pipeline
# Out:
# Pipeline(steps=[('feature_extraction',
#                  Pipeline(steps=[('lags_step',
#                                   FunctionTransformer(func=<function augment_lags at 0x157461300>,
#                                                       kw_args={'date_column': 'timestamp',
#                                                                'lags': [48,
#                                                                         336],
#                                                                'value_column': ['NetLoad']})),
#                                  ('dropnan_step',
#                                   FunctionTransformer(func=<function drop_na at 0x1353ea0c0>))])),
#                 ('scaling',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('feat_scaler',
#                                                   Pipeline(steps=[('scaler',
#                                                                    PowerTransformer())]),
#                                                   ['NetLoad_lag_48',
#                                                    'NetLoad_lag_336',
#                                                    'Temperature']),
#                                                  ('target_scaler',
#                                                   Pipeline(steps=[('target_scaler',
#                                                                    PowerTransformer(method='box-cox'))]),
#                                                   ['NetLoad'])],
#                                    verbose_feature_names_out=False))])

# %% [markdown]
# To apply the fitted transform to the data we call ```transform``` function. The transformed data will produce sequences of features and targets that can be directly consumed by a model, streamlining the forecasting process.

# %%
x, y = ds.transform(data.reset_index())

# %% [markdown]
# After fitting and transforming the dataset, you can proceed to analyze the transformed data, and train forecasting models using the prepared feature and target sequences.

# %% [markdown]
# ## Setting Up Visualization

# %%
import arviz as az
import matplotlib
import matplotlib.pyplot as plt

az.style.use(["science", "arviz-doc", "tableau-colorblind10"])
nice_fonts = {
    "savefig.bbox": "tight",
    "savefig.pad_inches": 0.05,
    "axes.labelsize": 8,
    "font.size": 8,
    "legend.fontsize": 8,
    "legend.frameon": False,
}
import matplotlib_inline.backend_inline

matplotlib_inline.backend_inline.set_matplotlib_formats(
    "svg", "pdf", "retina"
)  # For export

# %%
fig, ax = plt.subplots(1, 1, figsize=(4, 2))
ax.plot(x[0, :, :2])
# Out:
# [<matplotlib.lines.Line2D at 0x15751ad50>,
#  <matplotlib.lines.Line2D at 0x15660fd10>]

# %% [markdown]
#  Visualize the transformed data

# %%
with load_theme("boxy_light"):
    fig, ax = plt.subplots(1, 1, figsize=(4, 2))
    ax.plot(x[0, :, :2])
plt.show()

# %% [markdown]
# ## Building the Forecasting Model

# %% [markdown]
# To build the forecasting model, we first create an instance of ```MLPForecast```, a forecasting model from mlpforecast designed to handle time series forecasting tasks. One of the inputs to ```MLPForecast``` is the data pipeline created in the preceding cell. The  we define the following `model_hparams` as a dictionary.
#
# - **data_pipeline**: The fitted data pipeline from the previous steps.
# - **embedding_size**: Size of the embedding layer.
# - **embedding_type**: Type of embedding to use (set to `None` here).
# - **combination_type**: Method for combining features (set to `"addition-comb"`).
# - **hidden_size**: Number of hidden units in the model (256).
# - **num_layers**: Number of layers in the model (2).
# - **expansion_factor**: Factor for expanding the dimensionality of the data (2).
# - **residual**: Whether to use residual connections (set to `True`).
# - **activation_function**: Activation function for the model (set to `"SiLU"`).
# - **out_activation_function**: Activation function for output (set to `"Identity"`).
# - **dropout_rate**: Rate of dropout for regularization (0.2).
# - **alpha**: Parameter for the model (0.5).
# - **max_epochs**: Maximum number of epochs for training (10).

# %%
from mlpforecast.forecaster import (MLPForecast,
                                     MLPFQRForecast,
                                       MLPQRForecast, 
                                       MLPLaplaceForecast, 
                                       MLPMultivarGaussForecast)

model_hparams = {
    "data_pipeline": ds,
    "embedding_size": 16,
    "embedding_type": None,
    "combination_type": "addition-comb",
    "hidden_size": 256,
    "num_layers": 2,
    "expansion_factor": 2,
    "residual": True,
    "activation_function": "ReLU",
    "out_activation_function": "Identity",
    "dropout_rate": 0.2,
    "alpha": 0.05,
    "max_epochs": 20,
}
model_hparams.update(common_params)
model = MLPMultivarGaussForecast(
    exp_name="test", model_type="MLPMultivariate", hparams=model_hparams, rich_progress_bar=True
)

# %% [markdown]
# ## Training the Model
#
# To train the model, use the following code:
#
# ```python
# model.fit()
# ````

# %%
model.fit(data.reset_index()[:20000])
clear_output()
# Out:
# Seed set to 42
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# INFO:Forecaster:---------------Training started ---------------------------
# ┏━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name           ┃ Type                   ┃ Params ┃ Mode  ┃
# ┡━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ 0 │ tra_metric_fcn │ MeanAbsoluteError      │      0 │ train │
# │ 1 │ val_metric_fcn │ MeanAbsoluteError      │      0 │ train │
# │ 2 │ model          │ MCDMultForecastNetwork │  1.1 M │ train │
# └───┴────────────────┴────────────────────────┴────────┴───────┘
# Trainable params: 1.1 M
# Non-trainable params: 0
# Total params: 1.1 M
# Total estimated model params size (MB): 4
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 model.fit(data.reset_index()[:20000])
#       2 clear_output()
#
# File ~/Documents/projects/mlpforecast/mlpforecast/forecaster/common.py:289, in PytorchForecast.fit(self, train_df, val_df, train_ratio, drop_last, num_worker, batch_size, pin_memory)
#     285 logger.info("""---------------Training started ---------------------------""")
#     287 # Train the model and log training duration
# --> 289 self.trainer.fit(
#     290     self.model,
#     291     self.datamodule.train_dataloader(),
#     292     self.datamodule.val_dataloader(),
#     293     ckpt_path=get_latest_checkpoint(self.checkpoints),
#     294 )
#     296 self.train_walltime = default_timer() - start_time
#     297 logging.info(f"Training complete after {self.train_walltime / 60:.2f} minutes")
#
# File ~/opt/anaconda3/envs/mlpf/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py:543, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     541 self.state.status = TrainerStatus.RUNNING
#     542 self.training = True
# --> 543 call._call_and_handle_interrupt(
#     544     self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     545 )
#
# File ~/opt/anaconda3/envs/mlpf/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py:44, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      42     if trainer.strategy.launcher is not None:
#      43         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 44     return trainer_fn(*args, **kwargs)
#      46 except _TunerExitException:
#      47     _call_teardown_hook(trainer)
#
# File ~/opt/anaconda3/envs/mlpf/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py:579, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     572 assert self.state.fn is not None
#     573 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     574     self.state.fn,
#     575     ckpt_path,
#     576     model_provided=True,
#     577     model_connected=self.lightning_module is not None,
#     578 )
# --> 579 self._run(model, ckpt_path=ckpt_path)
#     581 assert self.state.stopped
#     582 self.training = False
#
# File ~/opt/anaconda3/envs/mlpf/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py:986, in Trainer._run(self, model, ckpt_path)
#     981 self._signal_connector.register_signal_handlers()
#     983 # ----------------------------
#     984 # RUN THE TRAINER
#     985 # ----------------------------
# --> 986 results = self._run_stage()
#     988 # ----------------------------
#     989 # POST-Training CLEAN UP
#     990 # ----------------------------
#     991 log.debug(f"{self.__class__.__name__}: trainer tearing down")
#
# File ~/opt/anaconda3/envs/mlpf/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py:1028, in Trainer._run_stage(self)
#    1026 if self.training:
#    1027     with isolate_rng():
# -> 1028         self._run_sanity_check()
#    1029     with torch.autograd.set_detect_anomaly(self._detect_anomaly):
#    1030         self.fit_loop.run()
#
# File ~/opt/anaconda3/envs/mlpf/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py:1057, in Trainer._run_sanity_check(self)
#    1054 call._call_callback_hooks(self, "on_sanity_check_start")
#    1056 # run eval step
# -> 1057 val_loop.run()
#    1059 call._call_callback_hooks(self, "on_sanity_check_end")
#    1061 # reset logger connector
#
# File ~/opt/anaconda3/envs/mlpf/lib/python3.11/site-packages/lightning/pytorch/loops/utilities.py:182, in _no_grad_context.<locals>._decorator(self, *args, **kwargs)
#     180     context_manager = torch.no_grad
#     181 with context_manager():
# --> 182     return loop_run(self, *args, **kwargs)
#
# File ~/opt/anaconda3/envs/mlpf/lib/python3.11/site-packages/lightning/pytorch/loops/evaluation_loop.py:135, in _EvaluationLoop.run(self)
#     133     self.batch_progress.is_last_batch = data_fetcher.done
#     134     # run step hooks
# --> 135     self._evaluation_step(batch, batch_idx, dataloader_idx, dataloader_iter)
#     136 except StopIteration:
#     137     # this needs to wrap the `*_step` call too (not just `next`) for `dataloader_iter` support
#     138     break
#
# File ~/opt/anaconda3/envs/mlpf/lib/python3.11/site-packages/lightning/pytorch/loops/evaluation_loop.py:396, in _EvaluationLoop._evaluation_step(self, batch, batch_idx, dataloader_idx, dataloader_iter)
#     390 hook_name = "test_step" if trainer.testing else "validation_step"
#     391 step_args = (
#     392     self._build_step_args_from_hook_kwargs(hook_kwargs, hook_name)
#     393     if not using_dataloader_iter
#     394     else (dataloader_iter,)
#     395 )
# --> 396 output = call._call_strategy_hook(trainer, hook_name, *step_args)
#     398 self.batch_progress.increment_processed()
#     400 if using_dataloader_iter:
#     401     # update the hook kwargs now that the step method might have consumed the iterator
#
# File ~/opt/anaconda3/envs/mlpf/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py:311, in _call_strategy_hook(trainer, hook_name, *args, **kwargs)
#     308     return None
#     310 with trainer.profiler.profile(f"[Strategy]{trainer.strategy.__class__.__name__}.{hook_name}"):
# --> 311     output = fn(*args, **kwargs)
#     313 # restore current_fx when nested context
#     314 pl_module._current_fx_name = prev_fx_name
#
# File ~/opt/anaconda3/envs/mlpf/lib/python3.11/site-packages/lightning/pytorch/strategies/strategy.py:411, in Strategy.validation_step(self, *args, **kwargs)
#     409 if self.model != self.lightning_module:
#     410     return self._forward_redirection(self.model, self.lightning_module, "validation_step", *args, **kwargs)
# --> 411 return self.lightning_module.validation_step(*args, **kwargs)
#
# File ~/Documents/projects/mlpforecast/mlpforecast/model/base_model.py:118, in BaseForecastModel.validation_step(self, batch, batch_idx)
#     106 def validation_step(self, batch, batch_idx):
#     107     """
#     108     Perform a single validation step.
#     109
#    (...)
#     116         tensor: The loss value for the batch.
#     117     """
# --> 118     loss, metric = self.model.step(batch, self.val_metric_fcn)
#     119     self.log("val_loss", loss, prog_bar=True, logger=True)
#     120     self.log(f"val_{self.hparams['metric']}", metric, prog_bar=True, logger=True)
#
# File ~/Documents/projects/mlpforecast/mlpforecast/net/parametric.py:172, in MCDMultForecastNetwork.step(self, batch, metric_fn)
#     161 """
#     162 Training step for the network.
#     163
#    (...)
#     169     tuple: Tuple containing the loss and computed metric.
#     170 """
#     171 x, y = batch
# --> 172 z = self.compute_combined_projection_feature(x)
#     173 return self.parametric_net.step(z, y, metric_fn)
#
# File ~/opt/anaconda3/envs/mlpf/lib/python3.11/site-packages/torch/nn/modules/module.py:1729, in Module.__getattr__(self, name)
#    1727     if name in modules:
#    1728         return modules[name]
# -> 1729 raise AttributeError(f"'{type(self).__name__}' object has no attribute '{name}'")
#
# AttributeError: 'MCDMultForecastNetwork' object has no attribute 'compute_combined_projection_feature'

# %% [markdown]
# To make predictions, use the following code:

# %%
out = model.predict(data.reset_index()[20000 : 20000 + 48 * 7 * 2])
clear_output()

# %%
x, y=next(iter(model.datamodule.val_dataloader()))
model.model.eval()
out=model.model.forecast(x)

fig, ax = plt.subplots(1, 1, figsize=(4, 2))
#ax.plot(out['q_samples'][-1, :, :, 0].T, 'k-', alpha=0.25)
ax.plot(out['loc'][-10, :, 0])
ax.plot(y[-10, :, 0])
#out['q_sample'][0, :, :, 0].shape
out.keys()
plt.show()

# %%
out['pdist'].sample((100,)).shape
# Out:
# torch.Size([100, 64, 48, 1])

# %%
fig, ax = plt.subplots(1, 1, figsize=(4, 2))
#ax.plot(out['q_samples'][-1, :, :, 0].T, 'k-', alpha=0.25)
ax.plot(out['pdist'].sample((100,))[:, -10, :, 0].T, color='k', alpha=0.23);
ax.plot(y[-10, :, 0])
#out['q_sample'][0, :, :, 0].shape
out.keys()
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(4, 2))
#ax.plot(out['q_samples'][-1, :, :, 0].T, 'k-', alpha=0.25)
ax.plot(out['D'][-10, :, 0])
#ax.plot(y[-10, :, 0])
#ax.set_ylim(0, 20)
#out['q_sample'][0, :, :, 0].shape
out.keys()
plt.show()

# %%
out['D']
# Out:
# tensor([[[[0.0949]],
#
#          [[0.0639]],
#
#          [[0.0586]],
#
#          ...,
#
#          [[0.1638]],
#
#          [[0.1569]],
#
#          [[0.1172]]],
#
#
#         [[[0.0828]],
#
#          [[0.0606]],
#
#          [[0.0581]],
#
#          ...,
#
#          [[0.1539]],
#
#          [[0.1360]],
#
#          [[0.0997]]],
#
#
#         [[[0.0766]],
#
#          [[0.0608]],
#
#          [[0.0612]],
#
#          ...,
#
#          [[0.1330]],
#
#          [[0.1131]],
#
#          [[0.0860]]],
#
#
#         ...,
#
#
#         [[[0.1015]],
#
#          [[0.1105]],
#
#          [[0.1098]],
#
#          ...,
#
#          [[0.0858]],
#
#          [[0.0877]],
#
#          [[0.0935]]],
#
#
#         [[[0.1285]],
#
#          [[0.1422]],
#
#          [[0.1482]],
#
#          ...,
#
#          [[0.0908]],
#
#          [[0.0972]],
#
#          [[0.1065]]],
#
#
#         [[[0.1564]],
#
#          [[0.1714]],
#
#          [[0.1815]],
#
#          ...,
#
#          [[0.0941]],
#
#          [[0.1101]],
#
#          [[0.1214]]]])

# %%
out['taus_hats'].sort(dim=1)[0][0, :, 0]

# %% [markdown]
# This command predicts the next 48*7*2 time steps based on the dataset. we can visualize the predictions as follows using ```mlpforecast.plot``` functionality

# %%
from mlpforecast.plot.visual_functions import plot_prediction

fig, ax = plt.subplots(1, 1, figsize=(6, 2))
ax = plot_prediction(ax, true=out["NetLoad"].values, mu=out["NetLoad_forecast"].values)
ax.set_ylim(0, 1500)
ax.set_ylabel("Power (MWh)")
fig.tight_layout(pad=1.08, h_pad=0.5, w_pad=0.5)

# %% [markdown]
# This code create a plot showing the true values versus the predicted values for "NetLoad", with the y-axis labeled in MWh and proper layout settings applied.

# %%
met = ["RMSE", "MAE", "MAPE(%)", "CORR", "R2-error", "NBIAS", "SMAPE(%)"]
model.metrics.groupby("target")[met].mean().round(2)

# %% [markdown]
# ## Backtesting the Model
# The library allows you to perform backtesting to evaluate the model across multiple time splits. Use the following code to set up backtesting:

# %%
from mlpforecast.evaluation.backtester import BacktestingForecast

backtest = BacktestingForecast(
    forecast_len=4,
    incremental_len=2,
    min_train_len=12,
    n_splits=10,
    window_type="expanding",
)

# %% [markdown]
# Next, you need to set up the model using partial:

# %%
from functools import partial

model = partial(MLPForecast, hparams=model_hparams, exp_name="bactesting")

# %% [markdown]
# To perform the backtesting, run the following code:

# %%
pred_df, metric_df = backtest.fit(data.reset_index(), model_instance=model)
clear_output()

# %% [markdown]
# Finally, to evaluate the results, you can compute the mean of metrics across folds:

# %%
metric_df.groupby(["target", "Folds"])[met].mean().round(2)

# %% [markdown]
# ## Hyper-parameter tuning

# %%
model = MLPForecast(hparams=model_hparams, exp_name="hyper")
model.auto_tune(data.reset_index()[:20000], data.reset_index()[:20000])

# %%
model.hparams
